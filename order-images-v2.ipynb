# %% [markdown]
# # Order Images

# %% [markdown]
# "classes": [
#       {
#         "class": "general_not_nsfw_not_suggestive",
#         "score": 0.0007875184342510781
#       },
#       {
#         "class": "general_nsfw",
#         "score": 0.004805508196563226
#       },
#       {
#         "class": "general_suggestive",
#         "score": 0.9944069733691856
#       },
#       {
#         "class": "no_female_underwear",
#         "score": 0.999999907547556
#       },
#       {
#         "class": "yes_female_underwear",
#         "score": 9.245244409257188e-8
#       },
#       {
#         "class": "no_male_underwear",
#         "score": 0.9999167015458665
#       },
#       {
#         "class": "yes_male_underwear",
#         "score": 0.00008329845413342512
#       },
#       {
#         "class": "no_sex_toy",
#         "score": 0.9999999910001268
#       },
#       {
#         "class": "yes_sex_toy",
#         "score": 8.999873232398837e-9
#       },
#       {
#         "class": "no_female_nudity",
#         "score": 0.9999995511767705
#       },
#       {
#         "class": "yes_female_nudity",
#         "score": 4.4882322944320716e-7
#       },
#       {
#         "class": "no_male_nudity",
#         "score": 0.9933864167281047
#       },
#       {
#         "class": "yes_male_nudity",
#         "score": 0.006613583271895247
#       },
#       {
#         "class": "no_female_swimwear",
#         "score": 0.9999999021606907
#       },
#       {
#         "class": "yes_female_swimwear",
#         "score": 9.783930920915306e-8
#       },
#       {
#         "class": "no_male_shirtless",
#         "score": 0.000003445936354991879
#       },
#       {
#         "class": "yes_male_shirtless",
#         "score": 0.9999965540636451
#       },
#       {
#         "class": "no_text",
#         "score": 0.8929050794787871
#       },
#       {
#         "class": "text",
#         "score": 0.10709492052121299
#       },
#       {
#         "class": "animated",
#         "score": 0.000011477072122517548
#       },
#       {
#         "class": "hybrid",
#         "score": 0.00002473947926558091
#       },
#       {
#         "class": "natural",
#         "score": 0.9999637834486119
#       },
#       {
#         "class": "animated_gun",
#         "score": 3.6664977793627756e-10
#       },
#       {
#         "class": "gun_in_hand",
#         "score": 2.7383169303324074e-9
#       },
#       {
#         "class": "gun_not_in_hand",
#         "score": 5.526734046634459e-9
#       },
#       {
#         "class": "no_gun",
#         "score": 0.9999999913682992
#       },
#       {
#         "class": "culinary_knife_in_hand",
#         "score": 6.875093699294034e-7
#       },
#       {
#         "class": "knife_in_hand",
#         "score": 0.000007976309549230896
#       },
#       {
#         "class": "knife_not_in_hand",
#         "score": 4.5930922437614927e-7
#       },
#       {
#         "class": "no_knife",
#         "score": 0.9999908768718565
#       },
#       {
#         "class": "a_little_bloody",
#         "score": 0.000001365436781137897
#       },
#       {
#         "class": "no_blood",
#         "score": 0.9999985632847668
#       },
#       {
#         "class": "other_blood",
#         "score": 1.2874755685833044e-8
#       },
#       {
#         "class": "very_bloody",
#         "score": 5.840369630097394e-8
#       },
#       {
#         "class": "no_pills",
#         "score": 0.9999999988570585
#       },
#       {
#         "class": "yes_pills",
#         "score": 1.1429414872810106e-9
#       },
#       {
#         "class": "no_smoking",
#         "score": 0.999999611998277
#       },
#       {
#         "class": "yes_smoking",
#         "score": 3.880017229881323e-7
#       },
#       {
#         "class": "illicit_injectables",
#         "score": 0.006486081761353505
#       },
#       {
#         "class": "medical_injectables",
#         "score": 6.604535444887517e-7
#       },
#       {
#         "class": "no_injectables",
#         "score": 0.9935132577851019
#       },
#       {
#         "class": "no_nazi",
#         "score": 0.9999999999676907
#       },
#       {
#         "class": "yes_nazi",
#         "score": 3.230916544490664e-11
#       },
#       {
#         "class": "no_kkk",
#         "score": 0.9999999999771634
#       },
#       {
#         "class": "yes_kkk",
#         "score": 2.283654884267044e-11
#       },
#       {
#         "class": "no_middle_finger",
#         "score": 0.9999980020441935
#       },
#       {
#         "class": "yes_middle_finger",
#         "score": 0.0000019979558065454636
#       },
#       {
#         "class": "no_terrorist",
#         "score": 0.9999999999669484
#       },
#       {
#         "class": "yes_terrorist",
#         "score": 3.305158026230673e-11
#       }
#     ]

# %% [markdown]
# ### Import base modules

# %% [markdown]
# ### Install dependencies

# %%
# !pip3 install PyQt5
# !pip3 install ipywidgets
# !pip3 install scikit-learn
# !pip3 install tensorflow_addons
# !pip3 install bs4
# !pip3 install fake_useragent
# !pip3 install pytest
# Out:
# Requirement already satisfied: PyQt5 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (5.15.6)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from PyQt5) (12.9.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from PyQt5) (5.15.2)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: ipywidgets in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (7.6.5)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipywidgets) (7.16.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipywidgets) (5.5.5)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipywidgets) (4.3.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: appnope in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: tornado>=4.2 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: jupyter-client in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: backcall in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (57.4.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.19)
# Requirement already satisfied: decorator in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (5.0.9)
# Requirement already satisfied: pygments in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (2.9.0)
# Requirement already satisfied: pickleshare in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.8.2)
# Requirement already satisfied: jupyter-core in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.15.0)
# Requirement already satisfied: wcwidth in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.0)
# Requirement already satisfied: jinja2 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.1)
# Requirement already satisfied: argon2-cffi in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.10.1)
# Requirement already satisfied: prometheus-client in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.7.1)
# Requirement already satisfied: nbconvert in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.0.7)
# Requirement already satisfied: pyzmq>=17 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (22.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.1)
# Requirement already satisfied: ptyprocess in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.14.5)
# Requirement already satisfied: pycparser in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: bleach in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: testpath in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.3)
# Requirement already satisfied: defusedxml in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.3)
# Requirement already satisfied: nest-asyncio in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.1)
# Requirement already satisfied: async-generator in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.10)
# Requirement already satisfied: packaging in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.9)
# Requirement already satisfied: webencodings in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.4.7)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: scikit-learn in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from scikit-learn) (1.5.4)
# Requirement already satisfied: numpy>=1.14.6 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from scikit-learn) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from scikit-learn) (1.1.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: tensorflow_addons in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (0.15.0)
# Requirement already satisfied: typeguard>=2.7 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from tensorflow_addons) (2.13.3)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: bs4 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from beautifulsoup4->bs4) (2.3.1)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: fake_useragent in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (0.1.11)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: pytest in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (6.2.5)
# Requirement already satisfied: attrs>=19.2.0 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from pytest) (21.2.0)
# Requirement already satisfied: toml in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from pytest) (0.10.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from pytest) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from pytest) (1.11.0)
# Requirement already satisfied: packaging in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from pytest) (20.9)
# Requirement already satisfied: iniconfig in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from pytest) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages (from packaging->pytest) (2.4.7)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/bin/python -m pip install --upgrade pip' command.

# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt
import hashlib
import sys
import random
import os
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from fake_useragent import UserAgent
from matplotlib.widgets import Button
import datetime
from tensorflow.keras import layers
import pathlib
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications import imagenet_utils
from imutils.object_detection import non_max_suppression
from PIL import Image
import scipy
import numpy as np
import argparse
import imutils
import time
import cv2
import requests
from IPython.display import clear_output
from io import BytesIO
from IPython.display import display, clear_output
#from ipywidgets import interact
#import ipywidgets as widgets
from PIL import ImageFilter
from bs4 import *
import requests
import uuid

# %% [markdown]
# ### main functions

# %%
def preview_pictures_from_directory(main_dir= "images_reinforce_test/neutral", start=0, end=10, figsize=(30, 30), dimensions=(224, 224)):

    del_dir = main_dir+"/.ipynb_checkpoints"
    # !rm -r $del_dir
    images_path = os.listdir(main_dir)
    if end==0:
        end = len(images_path)
    images = []
    for image_path in images_path[start:end]:
        image = Image.open(main_dir+"/"+image_path).resize(dimensions)
        images.append(image)
        
    rangeTot = len(images)
    print(rangeTot, " images found")
    count = 0
    plt.figure(figsize=figsize)
    for i in range(start, end):
        count+=1
        plt.subplot(rangeTot,int((rangeTot)/2),i+1)
        plt.subplots_adjust(hspace = 0.8)
        #color = "blue" if predicted_ids[i] == label_batch[i] else "red"
        plt.title(str(count))#, color=color)
        #plt.imshow(images[i]/255 if predicted_labels[i]=="neutral" else ndimage.gaussian_filter(images[i]/255, sigma=2))
        plt.imshow(images[i])


def order_images(main_dir, start=-1, end=-1, figsize=(30, 30), dimensions=(224, 224)):
    # %matplotlib inline
    from IPython.display import display, Markdown, clear_output
    from IPython.display import Image as IImage 
    import ipywidgets as widgets

    current  =  0
    del_dir = os.path.join(main_dir, ".ipynb_checkpoints")
    # !rm -r $del_dir
    if start == -1 and end == -1:
        images_path = os.listdir(main_dir)
    elif start != -1 and end == -1:
        images_path = os.listdir(main_dir)[start:len(os.listdir(main_dir))]
    elif start == -1 and end != -1:
        images_path = os.listdir(main_dir)[0:end]
    else:
        images_path = os.listdir(main_dir)
        
    next_button = widgets.Button(description='Next')
    prev_button = widgets.Button(description='Prev')
    move_button = widgets.Button(description='Move')
    class_names = os.listdir("images_new/")
    moving_paths = []

    path_selector = widgets.SelectMultiple(
        options=class_names,
        value=[],
        description='Fruits',
        disabled=False
    )
    output = widgets.Output()
    display(prev_button, next_button, output, path_selector, move_button)

    def on_next_button_clicked(_):
        global current
        if current+2 > len(images_path):
            return None
        moving_paths = []
        with output:
            current+=1
            clear_output()
            print("{0}/{1}".format(current+1, len(images_path)))
            pil_img = IImage(filename=os.path.join(main_dir, images_path[current]), width = dimensions[0], height=dimensions[1])
            display(pil_img)

    def on_prev_button_clicked(_):
        global current
        if current-1 < 0:
            return None
        moving_paths = []
        with output:
            current-=1
            clear_output()
            print("{0}/{1}".format(current+1, len(images_path)))
            pil_img = IImage(filename=os.path.join(main_dir, images_path[current]), width = dimensions[0], height=dimensions[1])
            display(pil_img)
    def on_move_button_clicked(_):
        with output:
            print(path_selector.value)
            for current_path in path_selector.value:
                os.system("cp '{0}' 'images_new/{1}'".format(os.path.join(main_dir, images_path[current]), current_path))

    next_button.on_click(on_next_button_clicked)
    prev_button.on_click(on_prev_button_clicked)
    move_button.on_click(on_move_button_clicked)

# %%
dump_dir = "images_backup/dump"
def clean_up_data_dir(data_dir):
    data_sub_directories = os.listdir(data_dir)
    for data_sub_directory in data_sub_directories:
        path_to_delete = os.path.join(data_dir, data_sub_directory, ".*")
        # !rm -r $path_to_delete

    # !rm -r $data_dir/.ipynb_checkpoints
    # !rm -r $data_dir/.DS_Store

# CREATE FOLDER
def folder_create(images, given_folder_name=""):
    try:
        folder_name = os.path.join(dump_dir, input("Enter Folder Name:- ") if given_folder_name == "" else given_folder_name)
        # folder creation
        os.mkdir(folder_name)
 
    # if folder exists with that name, ask another name
    except:
        print("Folder Exist with that name!")
        folder_create()
 
    # image downloading start
    download_images(images, folder_name)
 
 
# DOWNLOAD ALL IMAGES FROM THAT URL
def download_images(images, folder_name):
   
    # initial count is zero
    count = 0
 
    # print total images found in URL
    print(f"Total {len(images)} Image Found!")
 
    # checking if images is not zero
    if len(images) != 0:
        for i, image in enumerate(images):
            # From image tag ,Fetch image Source URL
 
                        # 1.data-srcset
                        # 2.data-src
                        # 3.data-fallback-src
                        # 4.src
 
            # Here we will use exception handling
 
            # first we will search for "data-srcset" in img tag
            try:
                # In image tag ,searching for "data-srcset"
                image_link = image["src"]
                 
            # then we will search for "data-src" in img
            # tag and so on..
            except:
                try:
                    # In image tag ,searching for "data-src"
                    image_link = image["data-src"]
                except:
                    try:
                        # In image tag ,searching for "data-fallback-src"
                        image_link = image["data-fallback-src"]
                    except:
                        try:
                            # In image tag ,searching for "src"
                            image_link = image["data-srcset"]
 
                        # if no Source URL found
                        except:
                            pass
 
            # After getting Image Source URL
            # We will try to get the content of image
            try:
                print("Downloading image: {0}/{1}; store => {2}".format(count, len(images), folder_name))
                r = requests.get(image_link).content
                try:
 
                    # possibility of decode
                    r = str(r, 'utf-8')
                except UnicodeDecodeError:
 
                    # After checking above condition, Image Download start
                    with open(f"{folder_name}/images{i+1}.jpg", "wb+") as f:
                        f.write(r)
 
                    # counting number of image downloaded
                    count += 1
            except:
                pass
 
        # There might be possible, that all
        # images not download
        # if all images download
        if count == len(images):
            print("All Images Downloaded!")
             
        # if all images not download
        else:
            print(f"Total {count} Images Downloaded Out of {len(images)}")
 
# MAIN FUNCTION START
def download_images_from_url(url, given_folder_name=""):
    if url == None or ( url.find("http") == -1 and url.find("www") == -1 ):
        return
    # content of URL
    ua = UserAgent()

    # Get list of user agents.


    # headers = {'User-Agent': ua.random}
    # r = requests.get(url, headers=headers)
    r = requests.get(url)
    print(url)
    print(r)
    # Parse HTML Code
    soup = BeautifulSoup(r.text, 'html.parser')
 
    # find all images in URL
    images = soup.findAll('img')
 
    # Call folder create function
    folder_create(images, given_folder_name)

def remove_duplicates(dir, include_src=False):
    hashMap = {}
    # List to store deleted files
    deletedFiles = []
    source_dup_file = []
    filelist = os.listdir(dir)
    for f in filelist:
        f = os.path.join(dir, f)
        key = hashFile(f)
        # If key already exists, it deletes the file
        if key in hashMap.keys():
            deletedFiles.append(f)
            if include_src:
                try:
                    index = source_dup_file.index(key)
                except Exception as e:
                    source_dup_file.append(key)
            os.remove(f)
        else:
            hashMap[key] = f
    if include_src:
        for key in source_dup_file:
            deletedFiles.append(f)
            os.remove(hashMap[key])
            
    if len(deletedFiles) != 0:  
        for deleted_file in deletedFiles:
            print('Deleted Files {0}'.format(deleted_file))
        print("total deleted => {}".format(len(deletedFiles)))
    else:
        print('No duplicate files found')
    

def remove_small_files(dir, min_size=5):
    for root, _, files in os.walk(dir):
        for f in files:
            fullpath = os.path.join(root, f)
            try:
                if os.path.getsize(fullpath) < min_size * 1024:   #set file size in kb
                    print(fullpath)
                    os.remove(fullpath)
            except Exception as e:
                print("Error" + fullpath)

def rename_all_files(dir):
    for root, _, files in os.walk(dir):
        for f in files:
            fullpath = os.path.join(root, f)
            try:
                filename, file_extension = os.path.splitext(fullpath)
                newname = str(uuid.uuid1())+"."+file_extension
                os.rename(fullpath, os.path.join(dir, newname))
           
            except Exception as e:
                print(e)
                print("Error" + fullpath)

def remove_randomly_dir_files(dir, limit=2, percentage=0):
    files = os.listdir(dir)

    if(percentage != 0):
        limit = int((percentage * len(files)) / 100)

    print("Total files found : {}".format(len(files)))
    deleted_indexes = [-1]
    count = 0
    if limit >= len(files):
        print("limit >= len(files)")
        return 

    for i in range(0, limit):
        if len(deleted_indexes) > limit:
            print("len(deleted_index) > limit")
            break

        random_index = -1

        while ( random_index in deleted_indexes) == True:
            random_index = random.randint(0, len(files)-1)

        deleted_indexes.append(random_index)
        count+=1

        print("deleting {0}/{1}; index => {2}".format(i+1, limit, random_index))
        os.remove(os.path.join(dir, files[random_index]))

    print("Total deleted files {}".format(count))
    print("Total files remaining {}".format(len(os.listdir(dir))))
    
def hashFile(filename):
    # For large files, if we read it all together it can lead to memory overflow, So we take a blocksize to read at a time
    BLOCKSIZE = 65536
    hasher = hashlib.md5()
    with open(filename, 'rb') as file:
        # Reads the particular blocksize from file
        buf = file.read(BLOCKSIZE)
        while(len(buf) > 0):
            hasher.update(buf)
            buf = file.read(BLOCKSIZE)
    return hasher.hexdigest()

# %% [markdown]
# ### Declaring main variables

# %%
main_dir = "images_new/male_underwear"
brw_start = -1
brw_end = -1

# %% [markdown]
# ### Preview Images

# %%
preview_pictures_from_directory(main_dir)
# Out:
# rm: images_new/male_underwear/.ipynb_checkpoints: No such file or directory
# 10  images found

# %% [markdown]
# ### Order Images

# %%
dump_dir = "images_backup"
data_dir = "images_new"
max_image_per_class = 5000
max_image_per_severe_class = 2000
severe_classes = ["general_nsfw"]
unwanted_dirs = ["dump", "test"]

clean_up_data_dir(data_dir)
clean_up_data_dir(dump_dir)


dump_sub_directories = os.listdir(dump_dir)

os.system("rm -r {}/*".format(data_dir))
for dump_sub_directory in dump_sub_directories:
    if dump_sub_directory in unwanted_dirs:
        continue
        
    os.system("cp -r {0} {1}".format(os.path.join(dump_dir, dump_sub_directory), data_dir))
        
        
data_sub_directories = os.listdir(data_dir)
for data_sub_directory in data_sub_directories:
    files = os.listdir(os.path.join(data_dir, data_sub_directory))
    total_image_num = len(files)
    max_image = max_image_per_severe_class if (data_sub_directory in severe_classes) else max_image_per_class
    if total_image_num > max_image:
        remove_randomly_dir_files(os.path.join(data_dir, data_sub_directory), limit=(total_image_num - max_image))        
        print("found {0} for class {1}; removing {2}".format(total_image_num, data_sub_directory, total_image_num - max_image))
    else:
        print("found {0} for class {1}; removing 0".format(total_image_num, data_sub_directory))
# Out:
# zsh:1: no matches found: images_new/male_shirtless/.*
# zsh:1: no matches found: images_new/general_not_nsfw_not_suggestive/.*
# zsh:1: no matches found: images_new/female_underwear/.*
# zsh:1: no matches found: images_new/female_nudity/.*
# zsh:1: no matches found: images_new/male_underwear/.*
# zsh:1: no matches found: images_new/female_swimwear/.*
# zsh:1: no matches found: images_new/sex_toys/.*
# zsh:1: no matches found: images_new/general_nsfw/.*
# rm: images_new/.ipynb_checkpoints: No such file or directory
# rm: images_new/.DS_Store: No such file or directory
# zsh:1: no matches found: images_backup/male_shirtless/.*
# zsh:1: no matches found: images_backup/dump/.*
# zsh:1: no matches found: images_backup/test/.*
# zsh:1: no matches found: images_backup/general_not_nsfw_not_suggestive/.*
# zsh:1: no matches found: images_backup/female_underwear/.*
# zsh:1: no matches found: images_backup/female_nudity/.*
# zsh:1: no matches found: images_backup/male_underwear/.*
# zsh:1: no matches found: images_backup/female_swimwear/.*
# zsh:1: no matches found: images_backup/sex_toys/.*
# zsh:1: no matches found: images_backup/general_nsfw/.*
# rm: images_backup/.ipynb_checkpoints: No such file or directory
# rm: images_backup/.DS_Store: No such file or directory
# found 429 for class male_shirtless; removing 0
# found 2099 for class general_not_nsfw_not_suggestive; removing 0
# found 1517 for class female_underwear; removing 0
# found 3326 for class female_nudity; removing 0
# found 156 for class male_underwear; removing 0
# found 739 for class female_swimwear; removing 0
# found 472 for class sex_toys; removing 0
# Total files found : 13581
# deleting 1/11581; index => 5767
# deleting 2/11581; index => 9349
# deleting 3/11581; index => 6940
# deleting 4/11581; index => 7903
# deleting 5/11581; index => 1744
# deleting 6/11581; index => 10995
# deleting 7/11581; index => 2819
# deleting 8/11581; index => 4393
# deleting 9/11581; index => 9636
# deleting 10/11581; index => 11982
# deleting 11/11581; index => 12694
# deleting 12/11581; index => 6586
# deleting 13/11581; index => 3369
# deleting 14/11581; index => 12511
# deleting 15/11581; index => 6652
# deleting 16/11581; index => 1071
# deleting 17/11581; index => 8014
# deleting 18/11581; index => 10114
# deleting 19/11581; index => 2334
# deleting 20/11581; index => 9736
# deleting 21/11581; index => 10221
# deleting 22/11581; index => 10152
# deleting 23/11581; index => 12430
# deleting 24/11581; index => 820
# deleting 25/11581; index => 617
# deleting 26/11581; index => 4740
# deleting 27/11581; index => 5716
# deleting 28/11581; index => 5786
# deleting 29/11581; index => 10300
# deleting 30/11581; index => 12405
# deleting 31/11581; index => 11473
# deleting 32/11581; index => 7241
# deleting 33/11581; index => 5029
# deleting 34/11581; index => 12005
# deleting 35/11581; index => 5944
# deleting 36/11581; index => 2477
# deleting 37/11581; index => 6557
# deleting 38/11581; index => 5605
# deleting 39/11581; index => 12889
# deleting 40/11581; index => 10285
# deleting 41/11581; index => 4052
# deleting 42/11581; index => 853
# deleting 43/11581; index => 2171
# deleting 44/11581; index => 7843
# deleting 45/11581; index => 2054
# deleting 46/11581; index => 2566
# deleting 47/11581; index => 11768
# deleting 48/11581; index => 3388
# deleting 49/11581; index => 8279
# deleting 50/11581; index => 7764
# deleting 51/11581; index => 4169
# deleting 52/11581; index => 9912
# deleting 53/11581; index => 827
# deleting 54/11581; index => 13354
# deleting 55/11581; index => 2010
# deleting 56/11581; index => 6253
# deleting 57/11581; index => 454
# deleting 58/11581; index => 10625
# deleting 59/11581; index => 10555
# deleting 60/11581; index => 405
# deleting 61/11581; index => 10562
# deleting 62/11581; index => 12602
# deleting 63/11581; index => 1887
# deleting 64/11581; index => 2598
# deleting 65/11581; index => 3206
# deleting 66/11581; index => 11852
# deleting 67/11581; index => 11409
# deleting 68/11581; index => 374
# deleting 69/11581; index => 1738
# deleting 70/11581; index => 3602
# deleting 71/11581; index => 2374
# deleting 72/11581; index => 10838
# deleting 73/11581; index => 2159
# deleting 74/11581; index => 2852
# deleting 75/11581; index => 7555
# deleting 76/11581; index => 2336
# deleting 77/11581; index => 4561
# deleting 78/11581; index => 4285
# deleting 79/11581; index => 3083
# deleting 80/11581; index => 1809
# deleting 81/11581; index => 4911
# deleting 82/11581; index => 9433
# deleting 83/11581; index => 13263
# deleting 84/11581; index => 10184
# deleting 85/11581; index => 937
# deleting 86/11581; index => 11939
# deleting 87/11581; index => 8294
# deleting 88/11581; index => 1412
# deleting 89/11581; index => 7239
# deleting 90/11581; index => 10010
# deleting 91/11581; index => 12944
# deleting 92/11581; index => 8605
# deleting 93/11581; index => 12965
# deleting 94/11581; index => 7886
# deleting 95/11581; index => 9139
# deleting 96/11581; index => 4402
# deleting 97/11581; index => 10522
# deleting 98/11581; index => 5824
# deleting 99/11581; index => 5227
# deleting 100/11581; index => 11403
# deleting 101/11581; index => 7471
# deleting 102/11581; index => 2690
# deleting 103/11581; index => 8272
# deleting 104/11581; index => 2087
# deleting 105/11581; index => 2357
# deleting 106/11581; index => 6118
# deleting 107/11581; index => 727
# deleting 108/11581; index => 11729
# deleting 109/11581; index => 5195
# deleting 110/11581; index => 2213
# deleting 111/11581; index => 12107
# deleting 112/11581; index => 5008
# deleting 113/11581; index => 2494
# deleting 114/11581; index => 1293
# deleting 115/11581; index => 7236
# deleting 116/11581; index => 12365
# deleting 117/11581; index => 11567
# deleting 118/11581; index => 4523
# deleting 119/11581; index => 7752
# deleting 120/11581; index => 10853
# deleting 121/11581; index => 11915
# deleting 122/11581; index => 9259
# deleting 123/11581; index => 9448
# deleting 124/11581; index => 2025
# deleting 125/11581; index => 6981
# deleting 126/11581; index => 6624
# deleting 127/11581; index => 3078
# deleting 128/11581; index => 13500
# deleting 129/11581; index => 5340
# deleting 130/11581; index => 12201
# deleting 131/11581; index => 4848
# deleting 132/11581; index => 6660
# deleting 133/11581; index => 4097
# deleting 134/11581; index => 10382
# deleting 135/11581; index => 7506
# deleting 136/11581; index => 6390
# deleting 137/11581; index => 12260
# deleting 138/11581; index => 6024
# deleting 139/11581; index => 9276
# deleting 140/11581; index => 12633
# deleting 141/11581; index => 4270
# deleting 142/11581; index => 12273
# deleting 143/11581; index => 4833
# deleting 144/11581; index => 6867
# deleting 145/11581; index => 4067
# deleting 146/11581; index => 1779
# deleting 147/11581; index => 6693
# deleting 148/11581; index => 6355
# deleting 149/11581; index => 6917
# deleting 150/11581; index => 4202
# deleting 151/11581; index => 8912
# deleting 152/11581; index => 2348
# deleting 153/11581; index => 5774
# deleting 154/11581; index => 577
# deleting 155/11581; index => 8027
# deleting 156/11581; index => 10785
# deleting 157/11581; index => 4978
# deleting 158/11581; index => 640
# deleting 159/11581; index => 13123
# deleting 160/11581; index => 3667
# deleting 161/11581; index => 739
# deleting 162/11581; index => 10180
# deleting 163/11581; index => 10131
# deleting 164/11581; index => 6327
# deleting 165/11581; index => 3075
# deleting 166/11581; index => 2411
# deleting 167/11581; index => 8079
# deleting 168/11581; index => 6307
# deleting 169/11581; index => 5998
# deleting 170/11581; index => 12025
# deleting 171/11581; index => 2282
# deleting 172/11581; index => 13475
# deleting 173/11581; index => 1236
# deleting 174/11581; index => 764
# deleting 175/11581; index => 8337
# deleting 176/11581; index => 4815
# deleting 177/11581; index => 1448
# deleting 178/11581; index => 4738
# deleting 179/11581; index => 9697
# deleting 180/11581; index => 7776
# deleting 181/11581; index => 11419
# deleting 182/11581; index => 7861
# deleting 183/11581; index => 9879
# deleting 184/11581; index => 11129
# deleting 185/11581; index => 2190
# deleting 186/11581; index => 8093
# deleting 187/11581; index => 7144
# deleting 188/11581; index => 11921
# deleting 189/11581; index => 8423
# deleting 190/11581; index => 4717
# deleting 191/11581; index => 11318
# deleting 192/11581; index => 1246
# deleting 193/11581; index => 12307
# deleting 194/11581; index => 4745
# deleting 195/11581; index => 8269
# deleting 196/11581; index => 8893
# deleting 197/11581; index => 6180
# deleting 198/11581; index => 9525
# deleting 199/11581; index => 5843
# deleting 200/11581; index => 5247
# deleting 201/11581; index => 12688
# deleting 202/11581; index => 12015
# deleting 203/11581; index => 10408
# deleting 204/11581; index => 939
# deleting 205/11581; index => 2095
# deleting 206/11581; index => 12214
# deleting 207/11581; index => 602
# deleting 208/11581; index => 8794
# deleting 209/11581; index => 9974
# deleting 210/11581; index => 280
# deleting 211/11581; index => 2839
# deleting 212/11581; index => 970
# deleting 213/11581; index => 5750
# deleting 214/11581; index => 1120
# deleting 215/11581; index => 5783
# deleting 216/11581; index => 4664
# deleting 217/11581; index => 11094
# deleting 218/11581; index => 11407
# deleting 219/11581; index => 1723
# deleting 220/11581; index => 11787
# deleting 221/11581; index => 2943
# deleting 222/11581; index => 7212
# deleting 223/11581; index => 620
# deleting 224/11581; index => 1270
# deleting 225/11581; index => 9365
# deleting 226/11581; index => 9516
# deleting 227/11581; index => 13423
# deleting 228/11581; index => 769
# deleting 229/11581; index => 9136
# deleting 230/11581; index => 9369
# deleting 231/11581; index => 9722
# deleting 232/11581; index => 5093
# deleting 233/11581; index => 2791
# deleting 234/11581; index => 2295
# deleting 235/11581; index => 2092
# deleting 236/11581; index => 13303
# deleting 237/11581; index => 10383
# deleting 238/11581; index => 13335
# deleting 239/11581; index => 5134
# deleting 240/11581; index => 11587
# deleting 241/11581; index => 10807
# deleting 242/11581; index => 5235
# deleting 243/11581; index => 12516
# deleting 244/11581; index => 6872
# deleting 245/11581; index => 5234
# deleting 246/11581; index => 12716
# deleting 247/11581; index => 12576
# deleting 248/11581; index => 1194
# deleting 249/11581; index => 13353
# deleting 250/11581; index => 9640
# deleting 251/11581; index => 942
# deleting 252/11581; index => 9258
# deleting 253/11581; index => 7215
# deleting 254/11581; index => 1196
# deleting 255/11581; index => 7769
# deleting 256/11581; index => 10931
# deleting 257/11581; index => 9872
# deleting 258/11581; index => 10490
# deleting 259/11581; index => 11957
# deleting 647/11581; index => 4825
# deleting 648/11581; index => 11431
# deleting 649/11581; index => 8581
# deleting 650/11581; index => 5524
# deleting 651/11581; index => 4092
# deleting 652/11581; index => 7110
# deleting 653/11581; index => 11966
# deleting 654/11581; index => 428
# deleting 655/11581; index => 483
# deleting 656/11581; index => 2273
# deleting 657/11581; index => 2747
# deleting 658/11581; index => 12982
# deleting 659/11581; index => 8937
# deleting 660/11581; index => 3148
# deleting 661/11581; index => 1909
# deleting 662/11581; index => 10266
# deleting 663/11581; index => 1774
# deleting 664/11581; index => 513
# deleting 665/11581; index => 6548
# deleting 666/11581; index => 1274
# deleting 667/11581; index => 3824
# deleting 668/11581; index => 6059
# deleting 669/11581; index => 9960
# deleting 670/11581; index => 4794
# deleting 671/11581; index => 3891
# deleting 672/11581; index => 8108
# deleting 673/11581; index => 9989
# deleting 674/11581; index => 7264
# deleting 675/11581; index => 1550
# deleting 676/11581; index => 12257
# deleting 677/11581; index => 797
# deleting 678/11581; index => 9306
# deleting 679/11581; index => 11126
# deleting 680/11581; index => 10859
# deleting 681/11581; index => 11091
# deleting 682/11581; index => 4806
# deleting 683/11581; index => 5936
# deleting 684/11581; index => 10638
# deleting 685/11581; index => 4820
# deleting 686/11581; index => 12579
# deleting 687/11581; index => 4289
# deleting 688/11581; index => 3676
# deleting 689/11581; index => 1286
# deleting 690/11581; index => 11521
# deleting 691/11581; index => 1244
# deleting 692/11581; index => 12703
# deleting 693/11581; index => 8055
# deleting 694/11581; index => 13290
# deleting 695/11581; index => 410
# deleting 696/11581; index => 4765
# deleting 697/11581; index => 7496
# deleting 698/11581; index => 13573
# deleting 699/11581; index => 5751
# deleting 700/11581; index => 6252
# deleting 701/11581; index => 4221
# deleting 702/11581; index => 9842
# deleting 703/11581; index => 8548
# deleting 704/11581; index => 10390
# deleting 705/11581; index => 375
# deleting 706/11581; index => 3005
# deleting 707/11581; index => 6900
# deleting 708/11581; index => 9492
# deleting 709/11581; index => 4509
# deleting 710/11581; index => 10402
# deleting 711/11581; index => 12819
# deleting 712/11581; index => 229
# deleting 713/11581; index => 4317
# deleting 714/11581; index => 11670
# deleting 715/11581; index => 5446
# deleting 716/11581; index => 8628
# deleting 717/11581; index => 10023
# deleting 718/11581; index => 10556
# deleting 719/11581; index => 13323
# deleting 720/11581; index => 4153
# deleting 721/11581; index => 12542
# deleting 722/11581; index => 11540
# deleting 723/11581; index => 591
# deleting 724/11581; index => 9890
# deleting 725/11581; index => 13205
# deleting 726/11581; index => 530
# deleting 727/11581; index => 2666
# deleting 728/11581; index => 223
# deleting 729/11581; index => 5753
# deleting 730/11581; index => 11197
# deleting 731/11581; index => 3221
# deleting 732/11581; index => 11330
# deleting 733/11581; index => 160
# deleting 734/11581; index => 7132
# deleting 735/11581; index => 6450
# deleting 736/11581; index => 115
# deleting 737/11581; index => 13374
# deleting 738/11581; index => 13326
# deleting 739/11581; index => 12056
# deleting 740/11581; index => 4373
# deleting 741/11581; index => 6280
# deleting 742/11581; index => 7607
# deleting 743/11581; index => 858
# deleting 744/11581; index => 3973
# deleting 745/11581; index => 10682
# deleting 746/11581; index => 8997
# deleting 747/11581; index => 10222
# deleting 748/11581; index => 4239
# deleting 749/11581; index => 802
# deleting 750/11581; index => 6047
# deleting 751/11581; index => 6564
# deleting 752/11581; index => 179
# deleting 753/11581; index => 4961
# deleting 754/11581; index => 12249
# deleting 755/11581; index => 7791
# deleting 756/11581; index => 11854
# deleting 757/11581; index => 3690
# deleting 758/11581; index => 2768
# deleting 759/11581; index => 4753
# deleting 760/11581; index => 5396
# deleting 761/11581; index => 5562
# deleting 762/11581; index => 5869
# deleting 763/11581; index => 10967
# deleting 764/11581; index => 10198
# deleting 765/11581; index => 12080
# deleting 766/11581; index => 4009
# deleting 767/11581; index => 3330
# deleting 768/11581; index => 11151
# deleting 769/11581; index => 1188
# deleting 770/11581; index => 4344
# deleting 771/11581; index => 7457
# deleting 772/11581; index => 10246
# deleting 773/11581; index => 11875
# deleting 774/11581; index => 12735
# deleting 775/11581; index => 5287
# deleting 776/11581; index => 10811
# deleting 777/11581; index => 9487
# deleting 778/11581; index => 7743
# deleting 779/11581; index => 8541
# deleting 780/11581; index => 3273
# deleting 781/11581; index => 5106
# deleting 782/11581; index => 2101
# deleting 783/11581; index => 4051
# deleting 784/11581; index => 12807
# deleting 785/11581; index => 3520
# deleting 786/11581; index => 9190
# deleting 787/11581; index => 11718
# deleting 788/11581; index => 8469
# deleting 789/11581; index => 13182
# deleting 790/11581; index => 9484
# deleting 791/11581; index => 12863
# deleting 792/11581; index => 11565
# deleting 793/11581; index => 4553
# deleting 794/11581; index => 1843
# deleting 795/11581; index => 7741
# deleting 796/11581; index => 13418
# deleting 797/11581; index => 8555
# deleting 798/11581; index => 5741
# deleting 799/11581; index => 710
# deleting 800/11581; index => 5528
# deleting 801/11581; index => 2251
# deleting 802/11581; index => 2229
# deleting 803/11581; index => 2323
# deleting 804/11581; index => 13336
# deleting 805/11581; index => 7387
# deleting 806/11581; index => 4735
# deleting 807/11581; index => 964
# deleting 808/11581; index => 2991
# deleting 809/11581; index => 3274
# deleting 810/11581; index => 2989
# deleting 811/11581; index => 12676
# deleting 812/11581; index => 4658
# deleting 813/11581; index => 1996
# deleting 814/11581; index => 3493
# deleting 815/11581; index => 11955
# deleting 816/11581; index => 9709
# deleting 817/11581; index => 12898
# deleting 818/11581; index => 13088
# deleting 819/11581; index => 8135
# deleting 820/11581; index => 9228
# deleting 821/11581; index => 11288
# deleting 822/11581; index => 6846
# deleting 823/11581; index => 7330
# deleting 824/11581; index => 3795
# deleting 825/11581; index => 13138
# deleting 826/11581; index => 3919
# deleting 827/11581; index => 1963
# deleting 828/11581; index => 2052
# deleting 829/11581; index => 11889
# deleting 830/11581; index => 2337
# deleting 831/11581; index => 3480
# deleting 832/11581; index => 12847
# deleting 833/11581; index => 4511
# deleting 834/11581; index => 3944
# deleting 835/11581; index => 5075
# deleting 836/11581; index => 9669
# deleting 837/11581; index => 5076
# deleting 838/11581; index => 3321
# deleting 839/11581; index => 12434
# deleting 840/11581; index => 7921
# deleting 841/11581; index => 9411
# deleting 842/11581; index => 9408
# deleting 843/11581; index => 1926
# deleting 844/11581; index => 9435
# deleting 845/11581; index => 1153
# deleting 846/11581; index => 152
# deleting 847/11581; index => 5912
# deleting 848/11581; index => 12897
# deleting 849/11581; index => 13344
# deleting 850/11581; index => 10282
# deleting 851/11581; index => 10001
# deleting 852/11581; index => 8960
# deleting 853/11581; index => 2995
# deleting 854/11581; index => 10183
# deleting 855/11581; index => 3642
# deleting 856/11581; index => 13509
# deleting 857/11581; index => 5400
# deleting 858/11581; index => 237
# deleting 859/11581; index => 8077
# deleting 860/11581; index => 3413
# deleting 861/11581; index => 9618
# deleting 862/11581; index => 3547
# deleting 863/11581; index => 3599
# deleting 864/11581; index => 3696
# deleting 865/11581; index => 1741
# deleting 866/11581; index => 13063
# deleting 867/11581; index => 8798
# deleting 868/11581; index => 12587
# deleting 869/11581; index => 3435
# deleting 870/11581; index => 1155
# deleting 871/11581; index => 6906
# deleting 872/11581; index => 7554
# deleting 873/11581; index => 12619
# deleting 874/11581; index => 2182
# deleting 875/11581; index => 8962
# deleting 876/11581; index => 760
# deleting 877/11581; index => 225
# deleting 878/11581; index => 11463
# deleting 879/11581; index => 373
# deleting 880/11581; index => 10325
# deleting 881/11581; index => 11100
# deleting 882/11581; index => 4790
# deleting 883/11581; index => 2301
# deleting 884/11581; index => 12939
# deleting 885/11581; index => 6463
# deleting 886/11581; index => 3255
# deleting 887/11581; index => 11251
# deleting 888/11581; index => 9922
# deleting 889/11581; index => 2770
# deleting 890/11581; index => 356
# deleting 891/11581; index => 7627
# deleting 892/11581; index => 2400
# deleting 893/11581; index => 6926
# deleting 894/11581; index => 11428
# deleting 895/11581; index => 10679
# deleting 896/11581; index => 13437
# deleting 897/11581; index => 8117
# deleting 898/11581; index => 5318
# deleting 899/11581; index => 4435
# deleting 900/11581; index => 12544
# deleting 901/11581; index => 7564
# deleting 902/11581; index => 5279
# deleting 903/11581; index => 6526
# deleting 904/11581; index => 8687
# deleting 905/11581; index => 13408
# deleting 906/11581; index => 9730
# deleting 907/11581; index => 2299
# deleting 908/11581; index => 11385
# deleting 909/11581; index => 725
# deleting 910/11581; index => 3067
# deleting 911/11581; index => 9884
# deleting 912/11581; index => 3299
# deleting 913/11581; index => 1856
# deleting 914/11581; index => 12650
# deleting 915/11581; index => 1601
# deleting 916/11581; index => 13008
# deleting 917/11581; index => 12829
# deleting 918/11581; index => 7420
# deleting 919/11581; index => 1176
# deleting 920/11581; index => 7970
# deleting 921/11581; index => 12321
# deleting 922/11581; index => 1839
# deleting 923/11581; index => 3921
# deleting 924/11581; index => 4152
# deleting 925/11581; index => 3317
# deleting 926/11581; index => 1730
# deleting 927/11581; index => 12086
# deleting 928/11581; index => 279
# deleting 929/11581; index => 7445
# deleting 930/11581; index => 3656
# deleting 931/11581; index => 8383
# deleting 932/11581; index => 1831
# deleting 933/11581; index => 1292
# deleting 934/11581; index => 826
# deleting 935/11581; index => 7622
# deleting 936/11581; index => 2579
# deleting 937/11581; index => 9476
# deleting 938/11581; index => 521
# deleting 939/11581; index => 10204
# deleting 940/11581; index => 1514
# deleting 941/11581; index => 3745
# deleting 942/11581; index => 9229
# deleting 943/11581; index => 4
# deleting 944/11581; index => 10173
# deleting 945/11581; index => 10933
# deleting 946/11581; index => 1313
# deleting 947/11581; index => 9961
# deleting 948/11581; index => 736
# deleting 949/11581; index => 13122
# deleting 950/11581; index => 7640
# deleting 951/11581; index => 648
# deleting 952/11581; index => 11784
# deleting 953/11581; index => 1051
# deleting 954/11581; index => 12763
# deleting 955/11581; index => 12267
# deleting 956/11581; index => 2079
# deleting 957/11581; index => 13073
# deleting 958/11581; index => 29
# deleting 959/11581; index => 8507
# deleting 960/11581; index => 893
# deleting 961/11581; index => 5830
# deleting 962/11581; index => 10810
# deleting 963/11581; index => 7840
# deleting 964/11581; index => 8667
# deleting 965/11581; index => 11337
# deleting 966/11581; index => 11918
# deleting 967/11581; index => 3143
# deleting 968/11581; index => 10883
# deleting 969/11581; index => 5576
# deleting 970/11581; index => 6366
# deleting 971/11581; index => 5512
# deleting 972/11581; index => 4701
# deleting 973/11581; index => 6434
# deleting 974/11581; index => 4201
# deleting 975/11581; index => 3791
# deleting 976/11581; index => 11864
# deleting 977/11581; index => 7959
# deleting 978/11581; index => 12974
# deleting 979/11581; index => 8930
# deleting 980/11581; index => 9672
# deleting 981/11581; index => 3411
# deleting 982/11581; index => 3975
# deleting 983/11581; index => 4298
# deleting 984/11581; index => 286
# deleting 985/11581; index => 8819
# deleting 986/11581; index => 9639
# deleting 987/11581; index => 13537
# deleting 988/11581; index => 7198
# deleting 989/11581; index => 3253
# deleting 990/11581; index => 10274
# deleting 991/11581; index => 3646
# deleting 992/11581; index => 5360
# deleting 993/11581; index => 12333
# deleting 994/11581; index => 7416
# deleting 995/11581; index => 13457
# deleting 996/11581; index => 10958
# deleting 997/11581; index => 4513
# deleting 998/11581; index => 13468
# deleting 999/11581; index => 7251
# deleting 1000/11581; index => 796
# deleting 1001/11581; index => 5453
# deleting 1002/11581; index => 11389
# deleting 1003/11581; index => 504
# deleting 1004/11581; index => 11776
# deleting 1005/11581; index => 13365
# deleting 1006/11581; index => 1192
# deleting 1007/11581; index => 4506
# deleting 1008/11581; index => 6657
# deleting 1009/11581; index => 8154
# deleting 1010/11581; index => 3380
# deleting 1011/11581; index => 5238
# deleting 1012/11581; index => 11710
# deleting 1013/11581; index => 11123
# deleting 1014/11581; index => 5544
# deleting 1015/11581; index => 13017
# deleting 1016/11581; index => 1594
# deleting 1017/11581; index => 4259
# deleting 1018/11581; index => 12768
# deleting 1019/11581; index => 8858
# deleting 1020/11581; index => 5987
# deleting 1021/11581; index => 12319
# deleting 1022/11581; index => 10889
# deleting 1023/11581; index => 12983
# deleting 1024/11581; index => 11557
# deleting 1025/11581; index => 653
# deleting 1026/11581; index => 11689
# deleting 1027/11581; index => 940
# deleting 1028/11581; index => 5131
# deleting 1029/11581; index => 7735
# deleting 1030/11581; index => 3743
# deleting 1031/11581; index => 5705
# deleting 11553/11581; index => 11439
# deleting 11554/11581; index => 421
# deleting 11555/11581; index => 9707
# deleting 11556/11581; index => 2970
# deleting 11557/11581; index => 10910
# deleting 11558/11581; index => 953
# deleting 11559/11581; index => 2850
# deleting 11560/11581; index => 7317
# deleting 11561/11581; index => 7209
# deleting 11562/11581; index => 4106
# deleting 11563/11581; index => 8661
# deleting 11564/11581; index => 1624
# deleting 11565/11581; index => 1111
# deleting 11566/11581; index => 5083
# deleting 11567/11581; index => 239
# deleting 11568/11581; index => 976
# deleting 11569/11581; index => 5972
# deleting 11570/11581; index => 10583
# deleting 11571/11581; index => 5489
# deleting 11572/11581; index => 4546
# deleting 11573/11581; index => 7073
# deleting 11574/11581; index => 9281
# deleting 11575/11581; index => 5178
# deleting 11576/11581; index => 7846
# deleting 11577/11581; index => 10696
# deleting 11578/11581; index => 9613
# deleting 11579/11581; index => 5543
# deleting 11580/11581; index => 7884
# deleting 11581/11581; index => 8852
# Total deleted files 11581
# Total files remaining 2000
# found 13581 for class general_nsfw; removing 11581

# %% [markdown]
# ### Preprocess Dir Images

# %% [markdown]
# #### reduce images  number

# %%
data_dir = "images_new"
clean_up_data_dir(data_dir)
max_image_per_class = 5000
data_sub_directories = os.listdir(data_dir)
unwanted_dirs = ["dump", "test"]
for unwanted_dir in unwanted_dirs:
    try:
        del data_sub_directories[data_sub_directories.index(unwanted_dir)]
    except Exception as e:
        pass

for data_sub_directory in data_sub_directories:
    files = os.listdir(os.path.join(data_dir, data_sub_directory))
    total_image_num = len(files)
    if total_image_num > max_image_per_class:
        remove_randomly_dir_files(os.path.join(data_dir, data_sub_directory), limit=(total_image_num - max_image_per_class))

        print("found {0} for class {1}; removing {2}".format(total_image_num, data_sub_directory, total_image_num - max_image_per_class))
    else:
        print("found {0} for class {1}; removing 0".format(total_image_num, data_sub_directory))
# Out:
# zsh:1: no matches found: images_new/male_shirtless/.*
# zsh:1: no matches found: images_new/.DS_Store/.*
# zsh:1: no matches found: images_new/general_not_nsfw_not_suggestive/.*
# zsh:1: no matches found: images_new/female_underwear/.*
# zsh:1: no matches found: images_new/female_nudity/.*
# zsh:1: no matches found: images_new/male_underwear/.*
# zsh:1: no matches found: images_new/female_swimwear/.*
# zsh:1: no matches found: images_new/general_nsfw/.*
# rm: images_new/.ipynb_checkpoints: No such file or directory
# found 429 for class male_shirtless; removing 0
# found 2000 for class general_not_nsfw_not_suggestive; removing 0
# found 1517 for class female_underwear; removing 0
# found 2000 for class female_nudity; removing 0
# found 156 for class male_underwear; removing 0
# found 739 for class female_swimwear; removing 0
# found 2000 for class general_nsfw; removing 0

# %%
data_dir = "images_new"
clean_up_data_dir(data_dir)
data_sub_directories = os.listdir(data_dir)
unwanted_dirs = ["dump", "test"]
for unwanted_dir in unwanted_dirs:
    try:
        del data_sub_directories[data_sub_directories.index(unwanted_dir)]
    except Exception as e:
        pass

for data_sub_directory in data_sub_directories:
    print("found {0} for class {1}".format(len(os.listdir(os.path.join(data_dir, data_sub_directory))), data_sub_directory))
# Out:
# zsh:1: no matches found: images_new/.DS_Store/.*
# zsh:1: no matches found: images_new/female_underwear/.*
# zsh:1: no matches found: images_new/female_nudity/.*
# zsh:1: no matches found: images_new/female_swimwear/.*
# zsh:1: no matches found: images_new/general_nsfw/.*
# rm: images_new/.ipynb_checkpoints: No such file or directory
# found 2238 for class female_underwear
# found 1500 for class female_nudity
# found 739 for class female_swimwear
# found 1500 for class general_nsfw

# %%
for data_sub_directory in data_sub_directories:
    print("1# renaming files in {}".format(data_sub_directory))
    rename_all_files(os.path.join(data_dir, data_sub_directory))

#     print("2# removing too small files in {}".format(data_sub_directory))
#     remove_small_files(os.path.join(data_dir, data_sub_directory))

#     print("2# removing duplicate files in {}".format(data_sub_directory))
#     remove_duplicates(os.path.join(data_dir, data_sub_directory))
# Out:
# 1# renaming files in female_underwear
# 1# renaming files in female_nudity
# 1# renaming files in female_swimwear
# 1# renaming files in general_nsfw

# %% [markdown]
# #### removing certain images from a dir

# %%
# remove_randomly_dir_files(os.path.join(data_dir, "general_not_nsfw_not_suggestive"), percentage=50)
# remove_randomly_dir_files(os.path.join(data_dir, "general_not_nsfw_not_suggestive"), limit=100)

# %%
for data_sub_directory in data_sub_directories:
    print("found {0} for class {1}".format(len(os.listdir(os.path.join(data_dir, data_sub_directory))), data_sub_directory))
# Out:
# found 425 for class male_shirtless
# found 2107 for class general_not_nsfw_not_suggestive
# found 6141 for class daz
# found 839 for class female_nudity
# found 156 for class male_underwear
# found 2150 for class neutral
# found 917 for class female_swimwear
# found 1622 for class adult
# found 771 for class general_nsfw

# %% [markdown]
# ### Download Images from website

# %%
keywords = "male underwear"
images_download_main_data = [
    {
        "url_query": "https://unsplash.com/s/photos/{0}",
        "name": "unsplash",
        "start": 1,
        "end": 2,
    },
    {
    "url_query": "https://pixabay.com/fr/images/search/{0}/?pagi{1}",
    "name": "unsplash",
    "start": 1,
    "end": 2,
    }
]

for images_download_data  in images_download_main_data:
    for i in range(images_download_data["start"], images_download_data["end"]):
        store = keywords.replace(" ", "_")+"_"+images_download_data["name"]+"_"+str(uuid.uuid1())
        
        print("downloading images from {0}, page {1} / {2}; keywords  => {3}".format(images_download_data["name"], images_download_data["start"], images_download_data["end"], keywords))
        # print("storage => {0}".format(store))
        url = images_download_data["url_query"].format(keywords, i)
        download_images_from_url(url, store)
        # print("--renaming files in {}".format(store))
        # rename_all_files(os.path.join(dump_dir, store))
        print("--removing too small files in {}".format(store))
        remove_small_files(os.path.join(dump_dir, store))
        print("--removing duplicate files in {}".format(store))
        remove_duplicates(os.path.join(dump_dir, store), True)
# Out:
# downloading images from unsplash, page 1 / 2; keywords  => male underwear
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages/fake_useragent/utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages/fake_useragent/utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range
# https://unsplash.com/s/photos/male underwear
# <Response [200]>
# Total 92 Image Found!
# Downloading image: 0/92
# Downloading image: 0/92
# Downloading image: 1/92
# Downloading image: 2/92
# Downloading image: 3/92
# Downloading image: 4/92
# Downloading image: 5/92
# Downloading image: 6/92
# Downloading image: 7/92
# Downloading image: 8/92
# Downloading image: 9/92
# Downloading image: 10/92
# Downloading image: 11/92
# Downloading image: 12/92
# Downloading image: 13/92
# Downloading image: 14/92
# Downloading image: 15/92
# Downloading image: 16/92
# Downloading image: 17/92
# Downloading image: 18/92
# Downloading image: 19/92
# Downloading image: 20/92
# Downloading image: 21/92
# Downloading image: 22/92
# Downloading image: 23/92
# Downloading image: 24/92
# Downloading image: 25/92
# Downloading image: 26/92
# Downloading image: 27/92
# Downloading image: 28/92
# Downloading image: 29/92
# Downloading image: 30/92
# Downloading image: 31/92
# Downloading image: 32/92
# Downloading image: 33/92
# Downloading image: 34/92
# Downloading image: 35/92
# Downloading image: 36/92
# Downloading image: 37/92
# Downloading image: 38/92
# Downloading image: 39/92
# Downloading image: 40/92
# Downloading image: 41/92
# Downloading image: 42/92
# Downloading image: 43/92
# Downloading image: 44/92
# Downloading image: 45/92
# Downloading image: 46/92
# Downloading image: 47/92
# Downloading image: 48/92
# Downloading image: 49/92
# Downloading image: 50/92
# Downloading image: 51/92
# Downloading image: 52/92
# Downloading image: 53/92
# Downloading image: 54/92
# Downloading image: 55/92
# Downloading image: 56/92
# Downloading image: 57/92
# Downloading image: 58/92
# Downloading image: 59/92
# Downloading image: 60/92
# Downloading image: 61/92
# Downloading image: 62/92
# Downloading image: 63/92
# Downloading image: 64/92
# Downloading image: 65/92
# Downloading image: 66/92
# Downloading image: 67/92
# Downloading image: 68/92
# Downloading image: 69/92
# Downloading image: 70/92
# Downloading image: 71/92
# Downloading image: 72/92
# Downloading image: 73/92
# Downloading image: 74/92
# Downloading image: 75/92
# Downloading image: 76/92
# Downloading image: 77/92
# Downloading image: 78/92
# Downloading image: 79/92
# Downloading image: 80/92
# Downloading image: 81/92
# Downloading image: 82/92
# Downloading image: 83/92
# Downloading image: 84/92
# Downloading image: 85/92
# Downloading image: 86/92
# Downloading image: 87/92
# Downloading image: 87/92
# Downloading image: 87/92
# Downloading image: 88/92
# Total 88 Images Downloaded Out of 92
# --removing too small files in male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images51.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images79.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images87.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images91.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images85.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images53.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images57.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images81.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images83.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images55.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images69.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images59.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images71.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images65.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images73.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images67.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images63.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images77.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images49.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images61.jpg
# images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images75.jpg
# --removing duplicate files in male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images21.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images35.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images86.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images45.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images6.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images78.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images50.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images44.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images52.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images46.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images5.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images4.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images47.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images84.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images80.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images42.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images56.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images68.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images3.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images82.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images64.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images70.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images58.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images72.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images76.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images62.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images9.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images8.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images74.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images60.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images48.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images13.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images12.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images10.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images38.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images39.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images11.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images29.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images15.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images14.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images28.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images16.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# Deleted Files images_backup/dump/male_underwear_unsplash_3e6c3f24-7a02-11ec-8286-acde48001122/images17.jpg
# total deleted => 66
# downloading images from unsplash, page 1 / 2; keywords  => male underwear
# https://pixabay.com/fr/images/search/male underwear/?pagi1
# <Response [403]>
# Total 0 Image Found!
# --removing too small files in male_underwear_unsplash_66c6eb90-7a02-11ec-8286-acde48001122
# --removing duplicate files in male_underwear_unsplash_66c6eb90-7a02-11ec-8286-acde48001122
# No duplicate files found

# %% [markdown]
# ####  downloading images from hot porn photos

    "tanned",
    "cosplay",
    "tightbutt",
    "workout",
    "cougar",
    "19yearsold",
    "amateurwife",
    "cowgirl",
    "bigassblonde",
    "clit",
    "curvy",
    "outdoor",
    "emo",
    "erotica",
    "girlnextdoor",
    "gyno",
    "hotmom",
    "cuminmouth",
    "interracialanal",
    "interracialdp",
    "interracialteen",
    "lesbiananal",
    "medicalfetish",
    "nylon",
    "sharewife",
    "bigtits",
    "thai",
    "threesome",
    "tittyfuck",
    "tribbing",
    "trimmed",
    "panties",
    "underwater",
    "pantyhose",
    "vagina",
    "watersport",
    "party",
    "workfantasies",
    "young",
    "bignaturals",
    "blindfold",
    "wet",
    "piercing",
    "brazilian",
    "bride",
    "brunette",
    "army",
    "pissing",
    "pool",
    "butt",
    "handjob",
    "caught",
    "chinese",
    "bdsm",
    "classic",
    "bigblacktits",
    "highheels",
    "black",
    "bigbreasted",
    "blonde",
    "interracial",
    "bizzare",
    "college",
    "jeans",
    "beach",
    "bra",
    "saggytits",
    "british",
    "secretary",
    "selfpic",
    "bustyamateur",
    "car",
    "shaved",
    "asian",
    "cumontits",
    "cockride",
    "cumswapping",
    "corset",
    "dildo",
    "latex",
    "domination",
    "dp",
    "skinny",
    "facefuck",
    "facesitting",
    "fatty",
    "skirt",
    "spanking",
    "foursome",
    "farm",
    "sport",
    "spreading",
    "feet",
    "latina",
    "hospital",
    "stockings",
    "flashing",
    "strapon",
    "knees",
    "footjob",
    "leather",
    "tattoo",
    "european",
    "boots",
    "longhair",
    "gagging",
    "gangbang",
    "maturetits",
    "milfass",
    "gf",
    "girlfriend",
    "booty",
    "grandma",
    "tinytits",
    "humping",
    "inkedgirls",
    "interracialgangbang",
    "machine",
    "oldtits",
    "toys",
    "oriental",
    "fetish",
    "upskirt",
    "catfight",
    "perfectass",
    "mistress",
    "model",
    "masturbating",
    "petite",
    "pinup",
    "plumper",
    "muscle",
    "centerfold",
    "glasses",
    "selfshot",
    "sextoys",
    "old",
    "smallboobs",
    "spicygirls",
    "cfnm",
    "stripping",
    "amateur",
    "orgy",
    "analgape",
    "teenass",
    "teencameltoe",
    "teenpussy",
    "thong",
    "pegging",
    "pigtails",
    "tightpussy",
    "tongue",
    "underwear",
    "whip",
    "police",
    "pov",
    "groupsex",
    "retro",
    "reversegangbang",
    "rimjob",
    "brutal",
    "rimming",
    "nurse",
    "scissoring",
    "seduction",
    "selfie",
    "bald",
    "smoking",
    "socks",
    "spandex",
    "spanish",
    "office",
    "interracialgroupsex",
    "interraciallesbian",
    "interracialmom",
    "oiled",
    "striptease",
    "machinesex",
    "masturbation",
    "bbw",
    "bbc",
    "swingers",
    "sybian",
    "voluptuous",
]

# %%
keywords = [
    
# "standing",
# "cocksuck", 
# "fuck",
# "fatpussy",
# "asshole",
# "tugjob",
# "doublepenetration",
# "fingering",
# "cuminpussy",
# "hardcore",
# "doggystyle",
# "blowjob",
# "bisexuals",
# "roughsex",
# "pussylick",
# "internalcreampie",
# "bukkake",
# "assfucking",
# "fisting",
# "cumshot",
# "couplesex",
# "bigdick",
# "asslicking",
# "massage",
# "creampie",
# "bigcocks",
# "anal",
# "monstercock",
# "mmf",
# "ballsucking",
# "facial",
# "fuckingmachine",
# "forced",
# "balllicking",
# "deepthroat",
# "titjob",
# "3some",
# "assworship",
# "suckingtits",
# "ebony",
# "ffm",
# "fuckingfrombehind",
# "blowbang",
# "painfulanal",
# "bush",
# "clothedsex",
# "painful",
# "lezdom",
# "lesbianorgy",
# "lesbianhumping",
# "cowgirl",
# "cougar",
# "threesome",
# "screaming",
# "tribbing",
# "pantyhose",
# "handjob",
# "butt",
# "facesitting",
# "foursome",
# "machine",
# "dildo",
# "cumswapping",
# "dp",
# "facefuck",
# "spanking",
# "milfass",
# "brutal",
# "rimming",
# "machinesex",
# "cute",
# "pornstar",
# "pussy",
# "ass",
# "bigass",
# "undressing",
# "fitness",
# "nudegirls",
# "nipples",
# "bath",
# "fatass",
"upskirt",
"bikini",
"swimsuit",
"lingerie",
"panties",
"shorts",
"nonnude",
"yogapants",
"dress",
"clothed",
"t-shirt",
"jeans",
"skirt"

]

# %%
base_url = "http://www.hotpornphotos.com/{}/"

count = 1
for keyword in keywords:
    store = keyword.replace(" ", "_")+"_"+"hot_porn_photos_"+str(uuid.uuid1())
    
    print("{0}/{1} => downloading images for {2} from {3}".format(count, len(keywords), keyword, "hot_porn_photos_"))
    # print("storage => {0}".format(store))
    url = base_url.format(keyword)
    download_images_from_url(url, store)
    # print("--renaming files in {}".format(store))ss
    # rename_all_files(os.path.join(dump_dir, store))
    
    print("--removing too small files in {}".format(store))
    remove_small_files(os.path.join(dump_dir, store))


    print("--removing duplicate files in {}".format(store))
    remove_duplicates(os.path.join(dump_dir, store), True)

    count+=1
# Out:
# 1/13 => downloading images for upskirt from hot_porn_photos_
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages/fake_useragent/utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "/Users/macpro/.local/share/virtualenvs/holypics-SxDLhKSZ/lib/python3.9/site-packages/fake_useragent/utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range
# http://www.hotpornphotos.com/upskirt/
# <Response [200]>
# Total 351 Image Found!
# Downloading image: 0/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 0/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 1/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 2/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 3/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 4/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 5/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 6/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 7/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 8/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 9/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 10/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 11/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 12/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 13/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 14/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 15/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 16/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 17/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 18/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 19/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 20/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 21/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 22/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 23/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 24/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 25/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 26/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 27/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 28/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 29/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 30/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 31/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 32/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 33/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 34/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 35/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 36/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 37/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 38/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 39/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 40/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 41/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 42/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 43/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 44/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 45/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 46/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 47/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 48/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 49/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 50/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 51/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 52/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 53/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 54/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 55/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 56/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 57/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 58/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 59/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 60/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 61/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 62/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 63/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 64/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 65/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 66/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 67/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 68/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 69/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 70/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 71/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 72/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 73/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 74/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 75/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 76/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 77/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 78/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 79/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 80/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 81/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 82/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 83/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 84/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 85/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 86/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 87/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 88/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 89/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 90/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 91/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 92/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 93/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 94/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 95/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 96/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 97/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 98/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 99/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 100/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 101/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 102/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 103/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 104/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 105/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 106/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 107/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 108/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 109/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 110/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 111/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 112/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 113/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 114/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 115/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 116/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 117/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 118/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 119/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 120/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 121/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 122/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 123/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 124/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 125/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 126/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 127/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 128/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image: 129/351; store => images_backup/dump/upskirt_hot_porn_photos_56e7aa06-7ae4-11ec-9c23-acde48001122
# Downloading image:
351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 265/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 266/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 267/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 268/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 269/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 270/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 271/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 272/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 273/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 274/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 275/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 276/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 277/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 278/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 279/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 280/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 281/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 282/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 283/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 284/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 285/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 286/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 287/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 288/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 289/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 290/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 291/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 292/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 293/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 294/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 295/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 296/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 297/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 298/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 299/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 300/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 301/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 302/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 303/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 304/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 305/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 306/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 307/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 308/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 309/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 310/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 311/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 312/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 313/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 314/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 315/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 316/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 317/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 318/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 319/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 320/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 321/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 322/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 323/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 324/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 325/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 326/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 327/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 328/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 329/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 330/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 331/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 332/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 333/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 334/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 335/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 336/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 337/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 338/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 339/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 340/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 341/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 342/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 343/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 344/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 345/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 346/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 347/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 348/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Downloading image: 349/351; store => images_backup/dump/skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# Total 350 Images Downloaded Out of 351
# --removing too small files in skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# --removing duplicate files in skirt_hot_porn_photos_ff115330-7ae9-11ec-9c23-acde48001122
# No duplicate files found

# %% [markdown]
# ##### relevent hotpornphotos for dataset
#
#
# - general nfsw
#     - standing
#     - cocksuck
#     - fuck
#     - fatpussy
#     - asshole
#     - tugjob
#     - doublepenetration
#     - fingering
#     - cuminpussy
#     - hardcore
#     - doggystyle
#     - blowjob
#     - bisexuals
#     - roughsex
#     - pussylick
#     - internalcreampie
#     - bukkake
#     - assfucking
#     - fisting
#     - cumshot
#     - couplesex
#     - bigdick
#     - asslicking
#     - massage
#     - creampie
#     - bigcocks
#     - anal
#     - monstercock
#     - mmf
#     - ballsucking
#     - facial
#     - fuckingmachine
#     - forced
#     - balllicking
#     - deepthroat
#     - titjob
#     - 3some
#     - assworship
#     - suckingtits
#     - ebony
#     - ffm
#     - fuckingfrombehind
#     - blowbang
#     - painfulanal
#     - bush
#     - clothedsex
#     - painful
#     - lezdom
#     - lesbianorgy
#     - lesbianhumping
#     - cowgirl
#     - cougar
#     - threesome
#     - screaming
#     - tribbing
#     - pantyhose
#     - handjob
#     - butt
#     - facesitting
#     - foursome
#     - machine
#     - dildo
#     - cumswapping
#     - dp
#     - facefuck
#     - spanking
#     - milfass
#     - brutal
#     - rimming
#     - machinesex
# - female nudity
#     - cute
#     - pornstar
#     - pussy
#     - ass
#     - bigass
#     - undressing
#     - fitness
#     - nudegirls
#     - nipples
#     - bath
#     - fatass
#     - upskirt
#
#
# - female swimwear
#     - bikini
#     - swimsuit
#     - lingerie
#     - panties
#
# - sexy
#     - shorts
#     - nonnude
#     - yogapants
#     - dress
#     - clothed
#     - t-shirt
#     - jeans
#     - skirt

# %%
# url = input("Enter URL:- ")
# download_images_from_url(url)

# %% [markdown]
# ### Test

# %%
store = "male_underwear_unsplash_c747eca4-79ed-11ec-98c6-acde48001122"
# remove_small_files(os.path.join(dump_dir, store))
# remove_duplicates(os.path.join(dump_dir, store), True)
remove_randomly_dir_files(os.path.join(dump_dir, store), percentage=10)
# Out:
# Total files found : 20
# deleting 1/2; index => 2
# deleting 2/2; index => 5
# Total deleted files 2
# Total files remaining 18

# %%
## look for images on instagram and tumblr in order to balance the dataset

#https://www.instagram.com/explore/tags/maleshirtless/
#https://www.tumblr.com/search/male%20shirtless
